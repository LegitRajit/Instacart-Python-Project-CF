# %% [markdown]
# # Table of Contents

# %% [markdown]
# 01 Importing Libraries <br />
# 02 Importing Data <br />
# 03 Dataframe Merging <br />
# 04 Data Exporting

# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Data

# %%
# Creating basic CSV path
path = r'C:\Users\Rajit\Python\11-2023 Instacart Basket Analysis'

# %%
# Importing orders_products_combined.pkl
df_ords_prod_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# Importing products_clean.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_clean.csv'),index_col = False)

# %% [markdown]
# # 03 Dataframe Merging

# %%
df_ords_prod_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_prod_comb.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ## Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Merging ords_prod_comb and df_prods based on 'product_id'
df_merged = df_prods.merge(df_ords_prod_comb, on = 'product_id', indicator = 'exists')

# %%
df_merged.head(30)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# ...

# %%
df_merged['exists'].value_counts()
# Out:
# exists
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 17)

# %% [markdown]
# # Data Exporting

# %%
#Export df_merged in pkl format
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
